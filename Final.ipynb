# %% [markdown]
# # Best Neighborhoods in Pittsburgh

# %% [markdown]
# The goal of the analysis and what makes a neighborhood the best

# %%
import json

# Load all three JSON files
with open("neighborhoods_nate.json", "r") as f:
    nate_neighborhoods = set(json.load(f))

with open("neighborhoods_tony.json", "r") as f:
    tony_neighborhoods = set(json.load(f))

with open("neighborhoods_mason.json", "r") as f:
    mason_neighborhoods = set(json.load(f))


common_neighborhoods = nate_neighborhoods & tony_neighborhoods

print(f"Number of common neighborhoods: {len(common_neighborhoods)}")
print(common_neighborhoods)
# Out:
# Number of common neighborhoods: 85
# ...
